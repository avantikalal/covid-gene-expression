# %% [markdown]
# # 2. Alignment

# %% [markdown]
# ## 2.1 STAR index

# %%
# %%bash
# cd ~
# ~/software/STAR/STAR --runMode genomeGenerate --genomeDir ~/STAR_index --genomeFastaFiles ~/hg38.fa.gz --sjdbGTFfile hg38_rmsk_TE.gtf.gz --runThreadN 8 --sjdbOverhang 65 --readFilesCommand zcat

# %% [markdown]
# ## 2.2 STAR alignment

# %% [markdown]
# # 3. TEtranscripts

# %%
# %%bash
# cd ~
